# %% [markdown]
# # 1. Import Modules and Libraries

# %%
#Importing the necessary libraries and modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import os 
import cv2
from tqdm import tqdm 
import seaborn as sns
import joblib 
import warnings
import math
import pickle as pk
import datetime
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from imageio import imread
import imageio
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers,Model,Sequential
from tensorflow.keras.layers import Dropout,Activation,InputLayer,LSTM,GRU,Bidirectional,TimeDistributed,Flatten,Dense,BatchNormalization,MaxPooling2D,Conv2D,Input,Concatenate,LeakyReLU
warnings.filterwarnings('ignore')
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.layers import concatenate, add
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image_dataset_from_directory, image # new
from PIL import Image
from pathlib import Path
import imghdr
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11708\1982159732.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      17 from imageio import imread
#      18 import imageio
# ---> 19 import tensorflow as tf
#      20 import tensorflow.keras as keras
#      21 from tensorflow.keras import layers,Model,Sequential
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from tensorflow._api.v2 import __internal__
#      46 from tensorflow._api.v2 import __operators__
#      47 from tensorflow._api.v2 import audio
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\autograph\utils\context_managers.py:20
#      17 import contextlib
#      19 from tensorflow.python.framework import ops
# ---> 20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#      24   """Create a TF control dependency on the return values of a function.
#      25
#      26   If the function had no return value, a no-op context is returned.
#    (...)
#      32     A context manager.
#      33   """
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\ops\tensor_array_ops.py:42
#      40 from tensorflow.python.ops import gen_data_flow_ops
#      41 from tensorflow.python.ops import list_ops
# ---> 42 from tensorflow.python.ops import math_ops
#      43 from tensorflow.python.platform import tf_logging as logging
#      44 from tensorflow.python.saved_model import nested_structure_coder
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\ops\math_ops.py:90
#      88 from tensorflow.python.ops import gen_data_flow_ops
#      89 from tensorflow.python.ops import gen_math_ops
# ---> 90 from tensorflow.python.ops import gen_nn_ops
#      91 from tensorflow.python.ops import gen_sparse_ops
#      92 from tensorflow.python.ops import tensor_math_operator_overrides  # pylint: disable=unused-import
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\ops\gen_nn_ops.py:6008
#    6005   _result, = _result
#    6006   return _result
# -> 6008 LRNGrad = tf_export("raw_ops.LRNGrad")(_ops.to_raw_op(lrn_grad))
#    6011 def lrn_grad_eager_fallback(input_grads: Annotated[Any, TV_LRNGrad_T], input_image: Annotated[Any, TV_LRNGrad_T], output_image: Annotated[Any, TV_LRNGrad_T], depth_radius: int, bias: float, alpha: float, beta: float, name, ctx) -> Annotated[Any, TV_LRNGrad_T]:
#    6012   if depth_radius is None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\framework\ops.py:5978, in to_raw_op(f)
#    5974 # Copy `f` to get a new `__dict__`, otherwise `tf_export` will fail
#    5975 # due to double-registration.
#    5976 f = types.FunctionType(f.__code__, f.__globals__, f.__name__, f.__defaults__,
#    5977                        f.__closure__)
# -> 5978 return kwarg_only(f)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\util\tf_export.py:379, in kwarg_only(f)
#     371     raise TypeError(
#     372         '{f} only takes keyword args (possible keys: {kwargs}). '
#     373         'Please pass these args as kwargs instead.'.format(
#     374             f=f.__name__, kwargs=f_argspec.args
#     375         )
#     376     )
#     377   return f(**kwargs)
# --> 379 return tf_decorator.make_decorator(f, wrapper, decorator_argspec=f_argspec)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\util\tf_decorator.py:159, in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#     157 decorator_func.__original_wrapped__ = target
#     158 if decorator_argspec:
# --> 159   decorator_func.__signature__ = fullargspec_to_signature(
#     160       decorator_argspec)
#     161 elif callable(target):
#     162   try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\util\tf_decorator.py:86, in fullargspec_to_signature(fullargspec)
#      82 parameters = []
#      84 for arg in fullargspec.args:
#      85   parameters.append(
# ---> 86       inspect.Parameter(
#      87           arg,
#      88           inspect.Parameter.POSITIONAL_OR_KEYWORD,
#      89           default=defaults.get(arg, inspect.Parameter.empty),
#      90       )
#      91   )
#      93 if fullargspec.varargs is not None:
#      94   parameters.append(
#      95       inspect.Parameter(fullargspec.varargs, inspect.Parameter.VAR_POSITIONAL)
#      96   )
#
# File C:\Program Files\Python312\Lib\inspect.py:2731, in Parameter.__init__(self, name, kind, default, annotation)
#    2729 def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2730     try:
# -> 2731         self._kind = _ParameterKind(kind)
#    2732     except ValueError:
#    2733         raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#
# File C:\Program Files\Python312\Lib\enum.py:713, in EnumType.__call__(cls, value, names, module, qualname, type, start, boundary, *values)
#     708     """
#     709     classes/types should always be True.
#     710     """
#     711     return True
# --> 713 def __call__(cls, value, names=None, *values, module=None, qualname=None, type=None, start=1, boundary=None):
#     714     """
#     715     Either returns an existing member, or creates a new enum class.
#     716
#    (...)
#     738     `type`, if set, will be mixed in as the first base class.
#     739     """
#     740     if cls._member_map_:
#     741         # simple value lookup if members exist
#
# KeyboardInterrupt:

# %% [markdown]
# ## 1.1. Loading the Dataset

# %%
# Directory path to the CASIA v2.0 dataset
path = r'C:\Users\User\Documents\ML-finalproject\CASIAv2.0'

# Dictionary mapping dataset types to their respective subdirectories
ds_path = {
    'tp': '\CASIA2.0_revised\Tp',
    'gt': '\CASIA2.0_Groundtruth'
}

# %% [markdown]
# ### 1.1.a. Verify if the Dataset has been Loaded

# %%
#Sample files names in Tp images
os.listdir(path+ds_path['tp'])[:10]
# Out:
# ['Tp_D_CND_M_N_ani00018_sec00096_00138.jpg',
#  'Tp_D_CND_M_N_art00076_art00077_10289.jpg',
#  'Tp_D_CND_M_N_art00077_art00076_10290.jpg',
#  'Tp_D_CND_S_N_ani00073_ani00068_00193.jpg',
#  'Tp_D_CND_S_N_ind00078_ind00077_00476.jpg',
#  'Tp_D_CND_S_N_txt00028_txt00006_10848.jpg',
#  'Tp_D_CNN_M_B_nat00056_nat00099_11105.jpg',
#  'Tp_D_CNN_M_B_nat10139_nat00059_11949.jpg',
#  'Tp_D_CNN_M_B_nat10139_nat00097_11948.jpg',
#  'Tp_D_CNN_M_N_ani00023_ani00024_10205.jpg']

# %%
# List of filenames in Tp images directory
tp_files = os.listdir(path+ds_path['tp'])
print("Number of tampered images:", len(tp_files)) #5123
# Out:
# Number of tampered images: 5123

# %%
#Sample files names in Gt images
os.listdir(path+ds_path['gt'])[:10]
# Out:
# ['Tp_D_CND_M_N_ani00018_sec00096_00138_gt.png',
#  'Tp_D_CND_M_N_art00076_art00077_10289_gt.png',
#  'Tp_D_CND_M_N_art00077_art00076_10290_gt.png',
#  'Tp_D_CND_S_N_ani00073_ani00068_00193_gt.png',
#  'Tp_D_CND_S_N_ind00078_ind00077_00476_gt.png',
#  'Tp_D_CND_S_N_txt00028_txt00006_10848_gt.png',
#  'Tp_D_CNN_M_B_nat00056_nat00099_11105_gt.png',
#  'Tp_D_CNN_M_B_nat10139_nat00059_11949_gt.png',
#  'Tp_D_CNN_M_B_nat10139_nat00097_11948_gt.png',
#  'Tp_D_CNN_M_N_ani00023_ani00024_10205_gt.png']

# %%
# List of filenames in Tp images directory
gt_files = os.listdir(path+ds_path['gt'])
print("Number of groundtruth images:", len(gt_files)) #5123
# Out:
# Number of groundtruth images: 5123

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## 2.x. Tp: Converting Images from TIF to JPEG

# %%
# Function to convert TIF files to JPEG files and overwrite original TIF files
def convert_tif_to_jpeg(directory):
    tif_files = [file for file in os.listdir(directory) if file.endswith('.tif')]
    print(f"Found {len(tif_files)} TIF files in {directory}")
    
    converted_count = 0
    for file in tqdm(tif_files, desc="Converting TIF to JPEG"):
        try:
            # Open TIF file
            tif_path = os.path.join(directory, file)
            image = Image.open(tif_path)
            
            # Convert and save as JPEG (overwriting the original TIF file)
            jpeg_path = os.path.splitext(tif_path)[0] + '.jpg'
            image.convert('RGB').save(jpeg_path, 'JPEG')
            
            # Increment converted count
            converted_count += 1
            
            # Remove original TIF file
            os.remove(tif_path)
        except Exception as e:
            print(f"Error converting {file}: {e}")
    
    print(f"Successfully converted and replaced {converted_count} TIF files with JPEG")

# Convert TIF files to JPEG in 'Tp' directory
convert_tif_to_jpeg(path+ds_path['tp'])
# Out:
# Found 0 TIF files in C:\Users\User\Documents\ML-finalproject\CASIAv2.0\CASIA2.0_revised\Tp
# Converting TIF to JPEG: 0it [00:00, ?it/s]
# Successfully converted and replaced 0 TIF files with JPEG

# %%
print("Number of tampered images:", len(tp_files)) #5123
# Out:
# Number of tampered images: 5123

# %% [markdown]
# ## 2.x. Tp: Resizing Images to 512 by 512

# %%
# Directory containing the original images
tp_image_dir = r"C:\Users\User\Documents\ML-finalproject\CASIAv2.0\CASIA2.0_revised\Tp"

# Directory to save the resized images
tp_pp = r"C:\Users\User\Documents\ML-finalproject\IFL\casia_tts\tp_class"

# %%
# Counter to keep track of the number of tampered images resized and saved
tp_count_resized = 0

# %%
# Loop through each file in the tp_image_dir directory
for filename in tqdm(os.listdir(tp_image_dir), desc="Resizing Tampered Images"):
    # Construct the full path to the original image
    original_image_path = os.path.join(tp_image_dir, filename)

    # Open the image using PIL
    original_image = Image.open(original_image_path)

    # Check if image mode is RGBA
    if original_image.mode == 'RGBA':
        # Convert image to RGB format
        original_image = original_image.convert('RGB')
    elif len(original_image.getbands()) > 3:  # Check if image has more than 3 channels
        # Extract RGB channels
        r, g, b, _ = original_image.split()
        # Merge RGB channels
        original_image = Image.merge('RGB', (r, g, b))

    # Resize the image to 512x512 pixels
    resized_image = original_image.resize((512, 512))

    # Construct the full path to save the resized image in tp_pp directory
    resized_image_path = os.path.join(tp_pp, filename)

    # Save the resized image
    resized_image.save(resized_image_path)

    # Increment the counter
    tp_count_resized += 1

print(f"{tp_count_resized} images resized and saved successfully.")
# Out:
# Resizing Tampered Images: 100%|███████████████████████████████████████████████████| 5123/5123 [00:26<00:00, 194.21it/s]
# 5123 images resized and saved successfully.

# %%
# Create a set to store unique image dimensions and channels
unique_dimensions_tp = set()

# Loop through each file in the tp_pp directory with tqdm
for filename in tqdm(os.listdir(tp_pp), desc="Processing Tampered Images"):
    # Construct the full path to the tampered image
    image_path = os.path.join(tp_pp, filename)

    # Open the image using PIL
    image = Image.open(image_path)
    
    # Get the dimensions of the image
    width, height = image.size

    # Get the number of channels in the image
    num_channels = len(image.getbands())

    # Add the dimensions and number of channels to the set of unique dimensions
    unique_dimensions_tp.add((width, height, num_channels))

# Print the unique dimensions and channels
print("Unique dimensions and channels of tampered images:")
for dimensions in unique_dimensions_tp:
    print(f"Dimensions: {dimensions[:2]}, Channels: {dimensions[2]}")
# Out:
# Processing Tampered Images: 100%|█████████████████████████████████████████████████| 5123/5123 [00:37<00:00, 137.23it/s]
# Unique dimensions and channels of tampered images:
# Dimensions: (512, 512), Channels: 3

# %% [markdown]
# ## 2.x. Gt: Resizing Images to 512 by 512

# %%
# Directory containing the original ground truth images
gt_image_dir = r"C:\Users\User\Documents\ML-finalproject\CASIAv2.0\CASIA2.0_Groundtruth"

# Directory to save the resized ground truth images
gt_pp = r"C:\Users\User\Documents\ML-finalproject\IFL\gt_pp"

# %%
# Create the directory gt_pp if it does not exist
if not os.path.exists(gt_pp):
    os.makedirs(gt_pp)

# %%
# Counter to keep track of the number of ground truth images resized and saved
gt_count_resized = 0

# %%
# Loop through each file in the gt_image_dir directory
for filename in tqdm(os.listdir(gt_image_dir), desc="Resizing Ground Truth Images"):
    # Construct the full path to the original ground truth image
    original_gt_image_path = os.path.join(gt_image_dir, filename)

    # Open the ground truth image using PIL
    original_gt_image = Image.open(original_gt_image_path)

    # Convert the ground truth image to grayscale
    original_gt_image = original_gt_image.convert('L')

    # Resize the ground truth image to 512x512 pixels
    resized_gt_image = original_gt_image.resize((512, 512))

    # Convert the ground truth image to numpy array
    resized_gt_array = np.array(resized_gt_image)

    # Expand the dimensions to add a singleton channel
    resized_gt_array = np.expand_dims(resized_gt_array, axis=-1)

    # Construct the full path to save the resized ground truth image in gt_pp directory
    resized_gt_image_path = os.path.join(gt_pp, filename)

    # Save the resized ground truth image
    resized_gt_image = Image.fromarray(resized_gt_array[:, :, 0].astype(np.uint8))  # Convert back to PIL Image
    resized_gt_image.save(resized_gt_image_path)

    # Increment the counter
    gt_count_resized += 1

print(f"{gt_count_resized} images resized and saved successfully.")
# Out:
# Resizing Ground Truth Images: 100%|████████████████████████████████████████████████| 5123/5123 [01:09<00:00, 73.33it/s]
# 5123 images resized and saved successfully.

# %%
# Create a set to store unique image dimensions and channels
unique_dimensions_gt = set()

# Loop through each file in the tp_pp directory with tqdm
for filename in tqdm(os.listdir(gt_pp), desc="Processing Groundtruth Images"):
    # Construct the full path to the tampered image
    image_path = os.path.join(gt_pp, filename)

    # Open the image using PIL
    image = Image.open(image_path)

    # Get the dimensions of the image
    width, height = image.size

    # Get the number of channels in the image
    num_channels = len(image.getbands())

    # Add the dimensions and number of channels to the set of unique dimensions
    unique_dimensions_gt.add((width, height, num_channels))

# Print the unique dimensions and channels
print("Unique dimensions and channels of groundtruth images:")
for dimensions in unique_dimensions_gt:
    print(f"Dimensions: {dimensions[:2]}, Channels: {dimensions[2]}")
# Out:
# Processing Groundtruth Images: 100%|██████████████████████████████████████████████| 5123/5123 [00:37<00:00, 135.47it/s]
# Unique dimensions and channels of groundtruth images:
# Dimensions: (512, 512), Channels: 1

# %% [markdown]
# ## 2.x. casia_tts: Creating a Train, Test, and Split (80/20)

# %%
# Defining Seed
seed = 42
tf.random.set_seed(seed)

# %%
# Defining Batch Size
batch_size = 32

# %%
# Directory containing the preprocessed tampered images
tp_pp_dir = r"C:\Users\User\Documents\ML-finalproject\IFL\casia_tts\tp_class"

# %%
# Create training dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    tp_pp_dir,
    labels='inferred',
    label_mode=None,              # No labels needed since it's a single-class problem
    validation_split=0.2,         # 80/20 split
    subset="training",
    seed=seed,                    # For reproducibility
    image_size=(512, 512),        # Resize images if necessary
    batch_size=batch_size
)
# Out:
# Found 5123 files.
# Using 4099 files for training.

# %%
# Check the shape of the labels for the training dataset with tqdm
for batch in tqdm(train_ds, desc="Checking Training Labels Shape"):
    labels = batch  # No need for indexing since there are no labels
    print("Training Labels Shape:", labels.shape)
    break  # Only need to check the first batch
# Out:
# Checking Training Labels Shape:   0%|                                                          | 0/129 [00:00<?, ?it/s]
# Training Labels Shape: (32, 512, 512, 3)

# %%
# Directory path for the validation dataset
# val_ds_dir = r"C:\Users\User\Documents\ML-finalproject\IFL\casia_tts"

# %%
# Create validation dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    tp_pp_dir,
    labels='inferred',
    label_mode=None,            # No labels needed since it's a single-class problem
    validation_split=0.2,       # 80/20 split
    subset="validation",
    seed=seed,                  # For reproducibility
    image_size=(512, 512),      # Resize images if necessary
    batch_size=batch_size
)
# Out:
# Found 5123 files.
# Using 1024 files for validation.

# %%
# Prefetch and optimize datasets for better performance
train_ds = train_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## 2.x. Plotting a Preview of the Images: train_ds

# %%
# Create a figure with a 10x10-inch size for displaying images
plt.figure(figsize=(5, 5))

# Iterate over the first batch of images in the preprocessed training dataset
for images in train_ds.take(1):
    # Display the first 9 preprocessed images in a 3x3 grid
    for i in range(9):
        # Create a subplot for each image
        ax = plt.subplot(3, 3, i + 1)
        
        # Display the preprocessed image as a numpy array and convert it to uint8 datatype
        plt.imshow(images[i].numpy().astype("uint8"), cmap='gray')  # cmap='gray' for grayscale images
        
        # Disable axis ticks and labels
        plt.axis("off")
        
        # Break the loop if all 9 images have been displayed
        if i == 8:
            break

# Display the plot
plt.show()

# %% [markdown]
# ## 2.x. Plotting a Preview of the Images: val_ds

# %%
# Create a figure with a 10x10-inch size for displaying images
plt.figure(figsize=(5, 5))

# Iterate over the first batch of images in the preprocessed training dataset
for images in val_ds.take(1):
    # Display the first 9 preprocessed images in a 3x3 grid
    for i in range(9):
        # Create a subplot for each image
        ax = plt.subplot(3, 3, i + 1)
        
        # Display the preprocessed image as a numpy array and convert it to uint8 datatype
        plt.imshow(images[i].numpy().astype("uint8"), cmap='gray')  # cmap='gray' for grayscale images
        
        # Disable axis ticks and labels
        plt.axis("off")
        
        # Break the loop if all 9 images have been displayed
        if i == 8:
            break

# Display the plot
plt.show()

# %% [markdown]
# ## 2.x. Verifying Training and Validation set Structure

# %%
# Check the structure of the training dataset
print("Training Dataset Structure:")
print(train_ds.element_spec)
# Out:
# Training Dataset Structure:
# TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None)

# %%
# Check the structure of the validation dataset
print("Validation Dataset Structure:")
print(val_ds.element_spec)
# Out:
# Validation Dataset Structure:
# TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None)

# %% [markdown]
# ## 2.x. Checking for "None" Values in the Dataset

# %%
# Check for None values in the training dataset
print("Checking for None values in the training dataset:")
none_found = False
for batch in tqdm(train_ds, desc="Progress", unit="batch"): # /129, where 129 is the no. of batches in the dataset
    if None in batch.numpy():
        print("Found None value in training dataset.")
        none_found = True
        break

if not none_found:
    print("Found no None value in training dataset.")
# Out:
# Checking for None values in the training dataset:
# Progress: 100%|███████████████████████████████████████████████████████████████████| 129/129 [03:23<00:00,  1.58s/batch]
# Found no None value in training dataset.

# %% [markdown]
# # 3. Modeling

# %% [markdown]
# ## 3.1. Pre-trained U-Net Model

# %% [markdown]
# ### from: IFL_Part01.ipynb

# %%
# Define input tensor shape (512x512x3)
input_img = Input((512, 512, 3))

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    """
    A convolutional block consisting of two convolutional layers with optional batch normalization.

    Parameters:
        input_tensor (tensor): The input tensor to the convolutional block.
        n_filters (int): The number of filters (channels) in the convolutional layers.
        kernel_size (int, optional): The size of the convolutional kernel. Defaults to 3.
        batchnorm (bool, optional): Whether to apply batch normalization. Defaults to True.

    Returns:
        tensor: The output tensor after passing through the convolutional block.
    """
    # First convolutional layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)  # Apply batch normalization if enabled
    x = Activation("relu")(x)  # Apply ReLU activation function
    
    # Second convolutional layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)  # Apply batch normalization if enabled
    x = Activation("relu")(x)  # Apply ReLU activation function
    
    return x  # Return the output tensor

# %%
def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
# Build U-Net model with specified parameters
model_unet = get_unet(
    input_img, 
    n_filters=16, 
    dropout=0.05, 
    batchnorm=True
)

# Compile the model with appropriate loss function for binary segmentation
model_unet.compile(
    optimizer='adam', 
    loss='binary_crossentropy', 
    metrics=['accuracy']
)

# Print model summary
model_unet.summary() #Total params: 2,164,593, Trainable params: 2,161,649 (8.25 MB), Non-trainable params: 2,944 (11.50 KB)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 512, 512, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 512, 512, 16)      │             448 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 512, 512, 16)      │              64 │ conv2d[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 512, 512, 16)      │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 512, 512, 16)      │           2,320 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 512, 512, 16)      │              64 │ conv2d_1[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_1 (Activation)     │ (None, 512, 512, 16)      │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 256, 256, 16)      │               0 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 256, 256, 16)      │               0 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 256, 256, 32)      │           4,640 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 256, 256, 32)      │             128 │ conv2d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_2 (Activation)     │ (None, 256, 256, 32)      │               0 │ batch_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 256, 256, 32)      │           9,248 │ activation_2[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 256, 256, 32)      │             128 │ conv2d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_3 (Activation)     │ (None, 256, 256, 32)      │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 128, 128, 32)      │               0 │ activation_3[0][0]         │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 128, 128, 32)      │               0 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 128, 128, 64)      │          18,496 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 128, 128, 64)      │             256 │ conv2d_4[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_4 (Activation)     │ (None, 128, 128, 64)      │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 128, 128, 64)      │          36,928 │ activation_4[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 128, 128, 64)      │             256 │ conv2d_5[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_5 (Activation)     │ (None, 128, 128, 64)      │               0 │ batch_normalization_5[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 64, 64, 64)        │               0 │ activation_5[0][0]         │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 64, 64, 64)        │               0 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 64, 64, 128)       │          73,856 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 64, 64, 128)       │             512 │ conv2d_6[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_6 (Activation)     │ (None, 64, 64, 128)       │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 64, 64, 128)       │         147,584 │ activation_6[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 64, 64, 128)       │             512 │ conv2d_7[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_7 (Activation)     │ (None, 64, 64, 128)       │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 32, 32, 128)       │               0 │ activation_7[0][0]         │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 32, 32, 128)       │               0 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 32, 32, 256)       │         295,168 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 32, 32, 256)       │           1,024 │ conv2d_8[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_8 (Activation)     │ (None, 32, 32, 256)       │               0 │ batch_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 32, 32, 256)       │         590,080 │ activation_8[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 32, 32, 256)       │           1,024 │ conv2d_9[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_9 (Activation)     │ (None, 32, 32, 256)       │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose              │ (None, 64, 64, 128)       │         295,040 │ activation_9[0][0]         │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 64, 64, 256)       │               0 │ conv2d_transpose[0][0],    │
# │                               │                           │                 │ activation_7[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 64, 64, 256)       │               0 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 64, 64, 128)       │         295,040 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 64, 64, 128)       │             512 │ conv2d_10[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_10 (Activation)    │ (None, 64, 64, 128)       │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 64, 64, 128)       │         147,584 │ activation_10[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 64, 64, 128)       │             512 │ conv2d_11[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_11 (Activation)    │ (None, 64, 64, 128)       │               0 │ batch_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_1            │ (None, 128, 128, 64)      │          73,792 │ activation_11[0][0]        │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 128, 128, 128)     │               0 │ conv2d_transpose_1[0][0],  │
# │                               │                           │                 │ activation_5[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 128, 128, 128)     │               0 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 128, 128, 64)      │          73,792 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 128, 128, 64)      │             256 │ conv2d_12[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_12 (Activation)    │ (None, 128, 128, 64)      │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 128, 128, 64)      │          36,928 │ activation_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 128, 128, 64)      │             256 │ conv2d_13[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_13 (Activation)    │ (None, 128, 128, 64)      │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_2            │ (None, 256, 256, 32)      │          18,464 │ activation_13[0][0]        │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 256, 256, 64)      │               0 │ conv2d_transpose_2[0][0],  │
# │                               │                           │                 │ activation_3[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 256, 256, 64)      │               0 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 256, 256, 32)      │          18,464 │ dropout_6[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 256, 256, 32)      │             128 │ conv2d_14[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_14 (Activation)    │ (None, 256, 256, 32)      │               0 │ batch_normalization_14[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 256, 256, 32)      │           9,248 │ activation_14[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_15        │ (None, 256, 256, 32)      │             128 │ conv2d_15[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_15 (Activation)    │ (None, 256, 256, 32)      │               0 │ batch_normalization_15[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_3            │ (None, 512, 512, 16)      │           4,624 │ activation_15[0][0]        │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_3 (Concatenate)   │ (None, 512, 512, 32)      │               0 │ conv2d_transpose_3[0][0],  │
# │                               │                           │                 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_7 (Dropout)           │ (None, 512, 512, 32)      │               0 │ concatenate_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 512, 512, 16)      │           4,624 │ dropout_7[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_16        │ (None, 512, 512, 16)      │              64 │ conv2d_16[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_16 (Activation)    │ (None, 512, 512, 16)      │               0 │ batch_normalization_16[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 512, 512, 16)      │           2,320 │ activation_16[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_17        │ (None, 512, 512, 16)      │              64 │ conv2d_17[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_17 (Activation)    │ (None, 512, 512, 16)      │               0 │ batch_normalization_17[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 512, 512, 1)       │              17 │ activation_17[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,164,593 (8.26 MB)
#  Trainable params: 2,161,649 (8.25 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %% [markdown]
# ## 3.x. Model Callbacks, Checkpoints, and Logs

# %%
# Define the path where model checkpoints will be saved
checkPoint_path = r"C:\Users\User\Documents\ML-finalproject\IFL\model_checkpoints"

# %%
# Define the file path pattern for saving model weights with the correct .keras extension
filepath = checkPoint_path + "weights-improvement-{epoch:02d}-{val_accuracy:.2f}.keras"

# %%
# Define a ModelCheckpoint callback to save the best model weights based on validation accuracy
checkpoint = ModelCheckpoint(
    filepath,                               # File path pattern for saving model weights
    monitor='val_accuracy',                 # Metric to monitor for saving the best model
    verbose=1,                              # Verbosity mode (1: print updates, 0: silent)
    save_best_only=True,                    # Save only the best model based on the monitored metric
    mode='max'                              # Mode for optimizing the monitored metric (max: maximize accuracy)
)

# %%
# Define the directory path for TensorBoard logs
log_dir = r"C:\Users\User\Documents\ML-finalproject\IFL\model_logs_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
# Define a TensorBoard callback to log training metrics for visualization
tensorboard_callback = TensorBoard(
    log_dir=log_dir,                        # Directory path for storing TensorBoard logs
    histogram_freq=3                        # Frequency (in epochs) for computing histogram summaries
)

# %%
# Combine the callbacks into a list
callbacks_list = [
    checkpoint, 
    tensorboard_callback
]

# %% [markdown]
# ## 3.x. Model Fitting

# %%
max_epochs = 10
input_size = 512

# %%
history = model_unet.fit(
    train_ds,
    steps_per_epoch=len(train_ds),
    epochs=max_epochs,
    validation_data=val_ds,
    validation_steps=len(val_ds),
    callbacks=callbacks_list
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 history = model_unet.fit(
#       2     x=train_ds,
#       3     steps_per_epoch=len(train_ds),
#       4     epochs=max_epochs,
#       5     validation_data=val_ds,
#       6     validation_steps=len(val_ds),
#       7     callbacks=callbacks_list
#       8 )
#
# NameError: name 'model_unet' is not defined
